# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyenhau442001/FASHION_MNIST_CNN/blob/main/FASHION_MNIST_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import fashion_mnist
from sklearn import utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout,Conv2D,MaxPooling2D,Flatten
from tensorflow.keras.optimizers import RMSprop,Adam
import numpy as np
from keras.utils import np_utils
import pandas as pd
from keras.callbacks import EarlyStopping 
import matplotlib.pyplot as plt

# Load data
(x_train,y_train),(x_test,y_test)=fashion_mnist.load_data()

# Force to data type
x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train=x_train.reshape(60000,28,28,1)
x_test=x_test.reshape(10000,28,28,1)
# Divide in 255 to ensure value always between 0 and 1
x_train/=255
x_test/=255

# Convert labels to one hot-encoding
y_train=np_utils.to_categorical(y_train,10)
y_test=np_utils.to_categorical(y_test,10)


# Create model 
model = Sequential()
model.add(Conv2D(64,(3,3),activation='relu',input_shape=(28,28,1)))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3),input_shape=(28,28),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(10, activation='softmax'))
model.summary()

# Compile
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Training
history=model.fit(x_train,y_train,batch_size=128,epochs=500,verbose=1,validation_data=(x_test,y_test),callbacks=[EarlyStopping(monitor='val_loss',patience=20)])
# Plot
plt.plot(history.history['accuracy'])
plt.xlabel('epoch')
plt.legend(['accuracy'])
plt.show()

# Evaluate
score = model.evaluate(x_test, y_test, verbose=0)
print('Test error:',score[0])
print('Test accuracy: ',score[1])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 128)               204928
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 243,786
# Trainable params: 243,786
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 469/469 [==============================] - 84s 174ms/step - loss: 0.5217 - accuracy: 0.8145 - val_loss: 0.3892 - val_accuracy: 0.8630
# Epoch 2/500
# 469/469 [==============================] - 81s 173ms/step - loss: 0.3423 - accuracy: 0.8766 - val_loss: 0.3410 - val_accuracy: 0.8762
# Epoch 3/500
# 469/469 [==============================] - 79s 168ms/step - loss: 0.2968 - accuracy: 0.8927 - val_loss: 0.3227 - val_accuracy: 0.8807
# Epoch 4/500
# 469/469 [==============================] - 78s 166ms/step - loss: 0.2693 - accuracy: 0.9023 - val_loss: 0.2904 - val_accuracy: 0.8940
# Epoch 5/500
# 469/469 [==============================] - 77s 165ms/step - loss: 0.2419 - accuracy: 0.9118 - val_loss: 0.2684 - val_accuracy: 0.9009
# Epoch 6/500
# 469/469 [==============================] - 79s 169ms/step - loss: 0.2243 - accuracy: 0.9182 - val_loss: 0.2805 - val_accuracy: 0.8975
# Epoch 7/500
# 469/469 [==============================] - 80s 170ms/step - loss: 0.2046 - accuracy: 0.9255 - val_loss: 0.2481 - val_accuracy: 0.9079
# Epoch 8/500
# 469/469 [==============================] - 83s 176ms/step - loss: 0.1898 - accuracy: 0.9310 - val_loss: 0.2521 - val_accuracy: 0.9094
# Epoch 9/500
# 469/469 [==============================] - 78s 166ms/step - loss: 0.1771 - accuracy: 0.9347 - val_loss: 0.2531 - val_accuracy: 0.9089
# Epoch 10/500
# 469/469 [==============================] - 80s 170ms/step - loss: 0.1611 - accuracy: 0.9405 - val_loss: 0.2503 - val_accuracy: 0.9122
# Epoch 11/500
# 469/469 [==============================] - 81s 172ms/step - loss: 0.1474 - accuracy: 0.9454 - val_loss: 0.2500 - val_accuracy: 0.9118
# Epoch 12/500
# 469/469 [==============================] - 86s 184ms/step - loss: 0.1347 - accuracy: 0.9500 - val_loss: 0.2860 - val_accuracy: 0.9067
# Epoch 13/500
# 469/469 [==============================] - 86s 183ms/step - loss: 0.1249 - accuracy: 0.9546 - val_loss: 0.2719 - val_accuracy: 0.9105
# Epoch 14/500
# 469/469 [==============================] - 86s 183ms/step - loss: 0.1126 - accuracy: 0.9585 - val_loss: 0.2704 - val_accuracy: 0.9126
# Epoch 15/500
# 469/469 [==============================] - 86s 183ms/step - loss: 0.1012 - accuracy: 0.9626 - val_loss: 0.2904 - val_accuracy: 0.9072
# Epoch 16/500
# 469/469 [==============================] - 82s 174ms/step - loss: 0.0920 - accuracy: 0.9666 - val_loss: 0.2865 - val_accuracy: 0.9144
# Epoch 17/500
# 469/469 [==============================] - 78s 167ms/step - loss: 0.0820 - accuracy: 0.9703 - val_loss: 0.3081 - val_accuracy: 0.9111
# Epoch 18/500
# 469/469 [==============================] - 78s 167ms/step - loss: 0.0757 - accuracy: 0.9715 - val_loss: 0.3206 - val_accuracy: 0.9075
# Epoch 19/500
# 469/469 [==============================] - 78s 166ms/step - loss: 0.0685 - accuracy: 0.9749 - val_loss: 0.3605 - val_accuracy: 0.9039
# Epoch 20/500
# 469/469 [==============================] - 78s 167ms/step - loss: 0.0613 - accuracy: 0.9779 - val_loss: 0.3346 - val_accuracy: 0.9101
# Epoch 21/500
# 469/469 [==============================] - 78s 166ms/step - loss: 0.0572 - accuracy: 0.9793 - val_loss: 0.3680 - val_accuracy: 0.9120
# Epoch 22/500
# 469/469 [==============================] - 79s 169ms/step - loss: 0.0480 - accuracy: 0.9827 - val_loss: 0.3921 - val_accuracy: 0.9096
# Epoch 23/500
# 469/469 [==============================] - 81s 173ms/step - loss: 0.0450 - accuracy: 0.9841 - val_loss: 0.4212 - val_accuracy: 0.9090
# Epoch 24/500
# 469/469 [==============================] - 81s 173ms/step - loss: 0.0415 - accuracy: 0.9849 - val_loss: 0.4087 - val_accuracy: 0.9144
# Epoch 25/500
# 469/469 [==============================] - 77s 164ms/step - loss: 0.0392 - accuracy: 0.9860 - val_loss: 0.4835 - val_accuracy: 0.9079
# Epoch 26/500
# 469/469 [==============================] - 79s 168ms/step - loss: 0.0356 - accuracy: 0.9871 - val_loss: 0.4522 - val_accuracy: 0.9143
# Epoch 27/500
# 469/469 [==============================] - 78s 166ms/step - loss: 0.0338 - accuracy: 0.9877 - val_loss: 0.4920 - val_accuracy: 0.9073
# Test error: 0.4919685423374176
# Test accuracy:  0.9072999954223633

# %%
# Predict
n=int(input("Index ? "))
print(x_test.shape)

y_predict = model.predict(x_test[n].reshape(1,28,28,1))
print('Predicted value: ', np.argmax(y_predict))
print('Correct value: ',np.argmax(y_test[n]))
# Out:
# Index ? 5
# (10000, 28, 28, 1)
# Predicted value:  1
# Correct value:  1

# %%
from keras.datasets import fashion_mnist
import matplotlib.pyplot as plt
import numpy as np
(x_tr,y_tr),(x_t,y_t)=fashion_mnist.load_data()
for i in range(1,10):
  plt.subplot(330+i)
  plt.imshow(x_t[i],cmap='gray')
